# %%
##AND##
from sklearn.linear_model import Perceptron
import numpy as np
#input data (x1,x2)
x=np.array([
    [0,0],
    [0,1],
    [1,0],
    [1,1]
])
#AND outputs
y_and= np.array([0,0,0,1])
# CREATE and train Perceptron
clf=perception(max_iter=1000, eta0=1.0, tol=1e-3)
clf.fit(X,y_and)

#percceptions
print("AND Perception:",clf.predict(x))
print("AND weights:", clf.coef_, "Bias", clf.intercept_)
##OR##
from sklearn.linear_model import Perceptron 
import numpy as np 
#input data (x1,x2)
X=np.array ([

])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 14
#      12 y_and= np.array([0,0,0,1])
#      13 # CREATE and train perception
# ---> 14 clf=perception(max_iter=1000, eta0=1.0, tol=1e-3)
#      15 clf.fit(X,y_and)
#      17 #percceptions
#
# NameError: name 'perception' is not defined
